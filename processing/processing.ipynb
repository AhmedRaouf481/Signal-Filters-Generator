# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt

# %%
def all_Pass_Filter(zeros_list, poles_list, a_list):
    for index in a_list:
        poles_list.append(index)
        zeros_list.append(1/np.conj(index))

    return zeros_list, poles_list

# %%
a = [0.1, 0.2, 0.5]

zeros_list = [0.5, 0.8]
poles_list = []
zeros_list, poles_list = all_Pass_Filter(zeros_list, poles_list, a)
gain = 5
frequencies_values, complex_frequency_response = signal.freqz_zpk(zeros_list, poles_list, gain, fs=1000)
# print(w)
# print(complex_frequency_response)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1, 1, 1)
ax1.set_title('Digital filter frequency response')

ax1.plot(frequencies_values, 20 * np.log10(abs(complex_frequency_response)), 'b')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.set_xlabel('Frequency [Hz]')
ax1.grid(True)


# ax2 = ax1.twinx()
# angles = np.unwrap(np.angle(h))
# ax2.plot(w, angles, 'g')
# ax2.set_ylabel('Angle [radians]', color='g')

plt.axis('tight')
plt.show()

# %%
angles = np.unwrap(np.angle(complex_frequency_response))

fig = plt.figure()
ax1 = fig.add_subplot(1, 1, 1)
ax1.set_title('Digital filter frequency response')

ax1.plot(frequencies_values, angles, 'g')
ax1.set_ylabel('Amplitude [dB]', color='b')
ax1.set_xlabel('Frequency [Hz]')
ax1.grid(True)
